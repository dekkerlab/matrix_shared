# %%
import sys
sys.path.insert(0, '/net/proteome/home/nezar/local/devel/tools/functional/lib/')
sys.path.insert(0, '/net/proteome/home/nezar/local/devel/tools/genomebrowser/')
sys.path.insert(0, '/net/proteome/home/nezar/local/devel/tools/')
sys.path.insert(0, '/net/proteome/home/nezar/local/devel/bbifile/pykent/')
# %matplotlib inline

# %%
import bioframe

# %%
from collections import OrderedDict

import matplotlib as mpl
import seaborn as sns; sns.set_style('white')
import matplotlib.pyplot as plt
import numpy as np
import pandas
import h5py
import requests

from bioframe.tools import bedtools, tsv
import bioframe
# import piling
# from kent import bbi

chromsizes = bioframe.fetch_chromsizes('hg19')

# %%
def get_peak_files(db, centername, factor, prefix, suffix):
    base_url = 'http://hgdownload.cse.ucsc.edu/goldenPath/' + db + '/encodeDCC/' + centername
    r = requests.get(base_url + '/files.txt')
    filenames = []
    for line in r.text.split('\n'):
        filename = line.split('\t')[0]
        if ((filename.startswith(prefix) and 
             factor in filename and filename.endswith(suffix))):
            filenames.append(filename)
    
    urls = [(base_url + '/' + fn) for fn in filenames]
    names = [fn.replace(prefix, '').replace(suffix, '')
             for fn in filenames]
    return OrderedDict(zip(names, urls))

urls = pandas.Series(get_peak_files('hg19', 'wgEncodeAwgTfbsUniform', 'Ctcf', 'wgEncodeAwgTfbs', 'narrowPeak.gz'))

# %%
urls
# Out:
# BroadDnd41CtcfUniPk.                        http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadGm12878CtcfUniPk.                      http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadH1hescCtcfUniPk.                       http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadHelas3CtcfUniPk.                       http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadHepg2CtcfUniPk.                        http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadHmecCtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadHsmmCtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadHsmmtCtcfUniPk.                        http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadHuvecCtcfUniPk.                        http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadK562CtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadNhaCtcfUniPk.                          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadNhdfadCtcfUniPk.                       http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadNhekCtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadNhlfCtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# BroadOsteoblCtcfUniPk.                      http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibA549Ctcfsc5916Pcr1xDex100nmUniPk.       http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibA549Ctcfsc5916Pcr1xEtoh02UniPk.         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibEcc1CtcfcV0416102Dm002p1hUniPk.         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibH1hescCtcfsc5916V0416102UniPk.          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibHepg2Ctcfsc5916V0416101UniPk.           http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibK562CtcfcPcr1xUniPk.                    http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibK562Ctcflsc98982V0416101UniPk.          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibSknshraCtcfV0416102UniPk.               http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# HaibT47dCtcfsc5916V0416102Dm002p1hUniPk.    http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# SydhGm12878Ctcfsc15914c20UniPk.             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# SydhImr90CtcfbIggrabUniPk.                  http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# SydhK562CtcfbIggrabUniPk.                   http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UtaA549CtcfUniPk.                           http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UtaFibroblCtcfUniPk.                        http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UtaGlioblaCtcfUniPk.                        http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
#                                                                   ...
# UwHcfaaCtcfUniPk.                           http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHcmCtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHcpeCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHct116CtcfUniPk.                          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHeeCtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHek293CtcfUniPk.                          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHelas3CtcfUniPk.                          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHepg2CtcfUniPk.                           http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHffCtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHffmycCtcfUniPk.                          http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHl60CtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHmecCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHmfCtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHpafCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHpfCtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHreCtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHrpeCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHuvecCtcfUniPk.                           http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwHvmfCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwK562CtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwMcf7CtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwNb4CtcfUniPk.                             http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwNhdfneoCtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwNhekCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwNhlfCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwRptecCtcfUniPk.                           http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwSaecCtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwSknshraCtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwWerirb1CtcfUniPk.                         http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# UwWi38CtcfUniPk.                            http://hgdownload.cse.ucsc.edu/goldenPath/hg19...
# Length: 100, dtype: object

# %%
datasets = [bioframe.read_table(url, schema='narrowPeak') for url in urls]
for name, dataset in zip(urls.keys(), datasets):
    dataset['name'] = name

# %%
combined = pandas.concat(datasets, axis=0, ignore_index=True)

# %%
len(combined)
# Out:
# 4662435

# %%
combined = combined.sort_values(['chrom', 'start'])
combined.head(20)
# Out:
#         chrom   start     end                                   name  score  \
# 3443041  chr1   16110   16390                       UwHcpeCtcfUniPk.    170
# 977073   chr1   16118   16362               HaibK562CtcfcPcr1xUniPk.    110
# 2212315  chr1   16128   16358                   UtaMcf7CtcfVehUniPk.    200
# 2011602  chr1   16149   16339             UtaMcf7CtcfSerumstimUniPk.    227
# 1961618  chr1   16150   16350                 UtaMcf7CtcfEstroUniPk.    209
# 1890580  chr1   16155   16339                      UtaK562CtcfUniPk.    171
# 1752000  chr1   16165   16325                    UtaHelas3CtcfUniPk.    139
# 205350   chr1   91156   91580                  BroadHelas3CtcfUniPk.    183
# 3753955  chr1   91187   91563                     UwHffmycCtcfUniPk.    145
# 3191393  chr1   91198   91548                        UwHacCtcfUniPk.    115
# 4477686  chr1   91203   91533                      UwRptecCtcfUniPk.    220
# 2446265  chr1   91220   91516                    UwAg04450CtcfUniPk.    223
# 4027024  chr1   91221   91517                        UwHreCtcfUniPk.    144
# 3495784  chr1   91223   91513                     UwHct116CtcfUniPk.    115
# 2696485  chr1   91227   91543                       UwBe2cCtcfUniPk.    138
# 3878710  chr1   91240   91504                        UwHmfCtcfUniPk.    141
# 794718   chr1  104859  105089    HaibA549Ctcfsc5916Pcr1xEtoh02UniPk.    106
# 758568   chr1  104880  105080  HaibA549Ctcfsc5916Pcr1xDex100nmUniPk.     87
# 479144   chr1  138850  139274                    BroadK562CtcfUniPk.    166
# 4206813  chr1  138883  139153                       UwK562CtcfUniPk.    127
#
#         strand         fc  -log10p   -log10q  relSummit
# 3443041      .  26.708880       -1  5.069213        140
# 977073       .  17.292793       -1  4.964811        122
# 2212315      .  31.357125       -1  2.570631        115
# 2011602      .  35.560401       -1  4.976226         95
# 1961618      .  32.742278       -1  1.854809        100
# 1890580      .  26.766516       -1  5.104183         92
# 1752000      .  21.832632       -1  4.550656         80
# 205350       .  28.712648       -1  5.033589        212
# 3753955      .  22.782451       -1  4.408393        188
# 3191393      .  18.039930       -1  4.114358        175
# 4477686      .  34.520149       -1  5.065531        165
# 2446265      .  35.050675       -1  4.869871        148
# 4027024      .  22.623546       -1  5.087934        148
# 3495784      .  18.009296       -1  4.265850        145
# 2696485      .  21.633149       -1  4.531696        158
# 3878710      .  22.181076       -1  3.856799        132
# 794718       .  16.600989       -1  2.570587        115
# 758568       .  13.708533       -1  2.088917        100
# 479144       .  25.985851       -1  4.225718        212
# 4206813      .  19.973754       -1  4.182146        135

# %% [markdown]
# ### Cluster ze peaks

# %%
merge_dist = 5000

with tsv(combined) as i:
    out = bedtools.cluster(i=i.name, d=merge_dist)
    out.columns = list(combined.columns) + ['cluster_id']

grouped = out.groupby('cluster_id')
out['min_start'] = grouped.start.transform(np.min)
out['max_end'] = grouped.end.transform(np.max)

# %%
out.head(10)
# Out:
#   chrom  start    end                        name  score strand         fc  \
# 0  chr1  16110  16390            UwHcpeCtcfUniPk.    170      .  26.708880
# 1  chr1  16118  16362    HaibK562CtcfcPcr1xUniPk.    110      .  17.292793
# 2  chr1  16128  16358        UtaMcf7CtcfVehUniPk.    200      .  31.357125
# 3  chr1  16149  16339  UtaMcf7CtcfSerumstimUniPk.    227      .  35.560401
# 4  chr1  16150  16350      UtaMcf7CtcfEstroUniPk.    209      .  32.742278
# 5  chr1  16155  16339           UtaK562CtcfUniPk.    171      .  26.766516
# 6  chr1  16165  16325         UtaHelas3CtcfUniPk.    139      .  21.832632
# 7  chr1  91156  91580       BroadHelas3CtcfUniPk.    183      .  28.712648
# 8  chr1  91187  91563          UwHffmycCtcfUniPk.    145      .  22.782451
# 9  chr1  91198  91548             UwHacCtcfUniPk.    115      .  18.039930
#
#    -log10p   -log10q  relSummit  cluster_id  min_start  max_end
# 0       -1  5.069213        140           1      16110    16390
# 1       -1  4.964811        122           1      16110    16390
# 2       -1  2.570631        115           1      16110    16390
# 3       -1  4.976226         95           1      16110    16390
# 4       -1  1.854809        100           1      16110    16390
# 5       -1  5.104183         92           1      16110    16390
# 6       -1  4.550656         80           1      16110    16390
# 7       -1  5.033589        212           2      91156    91580
# 8       -1  4.408393        188           2      91156    91580
# 9       -1  4.114358        175           2      91156    91580

# %%
summary = pandas.DataFrame({
        'chrom': grouped.chrom.first(),
        'start': grouped.start.min(),
        'end': grouped.end.max(),
        'cluster_id': grouped.cluster_id.first(),
        'cluster_size': grouped.size(),
        'mean_fc': grouped.fc.mean(),
        'median_fc': grouped.fc.median(),
        'min_fc': grouped.fc.min(),
        'max_fc': grouped.fc.max(),
    }, 
    columns=['chrom', 'start', 'end', 'cluster_id', 'cluster_size', 'mean_fc', 'median_fc', 'min_fc', 'max_fc'])
summary = summary.reset_index(drop=True)
summary = summary.sort_values('mean_fc', ascending=False)
summary.head()
# Out:
#        chrom      start        end  cluster_id  cluster_size     mean_fc  \
# 19786  chr12   58299051   58299575       19787            99  421.795083
# 38062  chr17   78549087   78549594       38063           100  407.981867
# 19627  chr12   54773353   54773923       19628           102  406.092712
# 92652   chr9  130879847  130880377       92653           100  398.930859
# 4397    chr1  114887365  114889566        4398           102  391.848698
#
#         median_fc     min_fc      max_fc
# 19786  429.485396  64.739853  657.644949
# 38062  409.537269  60.714637  625.438059
# 19627  420.840471  25.300614  674.760266
# 92652  413.943237  53.019034  617.837592
# 4397   422.145632  14.918692  688.923138

# %%
out.to_csv('/net/levsha/share/nezar/ctcf_sites/ctcf.hg19.allEncodeUniformNarrowPeak.clustered.txt.gz', sep='\t', index=False, compression='gzip')
summary.to_csv('/net/levsha/share/nezar/ctcf_sites/ctcf.hg19.allEncodeUniformNarrowPeak.clusters.txt.gz', sep='\t', index=False, compression='gzip')

# %%
(summary.end-summary.start).hist(bins=100)

# %%
(summary.mean_fc).hist(bins=100, alpha=0.5)
(summary.max_fc).hist(bins=100, alpha=0.5)

# %%
#!jupyter-nbconvert --to=html --stdout cluster-ctcfs-mm9.ipynb > /net/proteome/home/nezar/public_html/notebooks/cluster-ctcfs-mm9.html
